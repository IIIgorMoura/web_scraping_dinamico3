# %% [markdown]
# # Tratamento

# %%
import pandas as pd
import numpy as np


df = pd.read_excel('casas.xlsx')
df
# Out:
#                       metragem                   quartos  \
# 0    Tamanho do imóvel\n604 m²  Quantidade de quartos\n4
# 1     Tamanho do imóvel\n60 m²  Quantidade de quartos\n2
# 2     Tamanho do imóvel\n75 m²                       NaN
# 3     Tamanho do imóvel\n43 m²  Quantidade de quartos\n1
# 4    Tamanho do imóvel\n161 m²  Quantidade de quartos\n3
# ..                         ...                       ...
# 100   Tamanho do imóvel\n27 m²  Quantidade de quartos\n2
# 101  Tamanho do imóvel\n525 m²                       NaN
# 102   Tamanho do imóvel\n37 m²  Quantidade de quartos\n2
# 103  Tamanho do imóvel\n146 m²  Quantidade de quartos\n3
# 104  Tamanho do imóvel\n400 m²                       NaN
#
#                         banheiros                              vagas  \
# 0      Quantidade de banheiros\n7  Quantidade de vagas de garagem\n3
# 1      Quantidade de banheiros\n2  Quantidade de vagas de garagem\n1
# 2      Quantidade de banheiros\n1  Quantidade de vagas de garagem\n2
# 3    Quantidade de banheiros\n1-2  Quantidade de vagas de garagem\n1
# 4      Quantidade de banheiros\n1                                NaN
# ..                            ...                                ...
# 100    Quantidade de banheiros\n1  Quantidade de vagas de garagem\n1
# 101                           NaN                                NaN
# 102    Quantidade de banheiros\n1                                NaN
# 103    Quantidade de banheiros\n3  Quantidade de vagas de garagem\n2
# 104                           NaN                                NaN
#
#                                            valor  \
# 0    R$ 11.800.000\nCond. R$ 1.659 • IPTU R$ 873
# 1         R$ 395.000\nCond. R$ 120 • IPTU R$ 130
# 2                                     R$ 350.000
# 3          R$ 180.000\nCond. R$ 430 • IPTU R$ 67
# 4                                     R$ 265.600
# ..                                           ...
# 100                                   R$ 199.900
# 101                     R$ 270.000\nCond. R$ 550
# 102                                   R$ 273.000
# 103   R$ 1.899.970\nCond. R$ 2.000 • IPTU R$ 700
# 104                    R$ 480.000\nIPTU R$ 2.459
#
#                            nomeRua
# 0                   Alameda Mamoré
# 1                      Rua Marília
# 2       Avenida Valentim Magalhães
# 3               Rua General Osório
# 4                              NaN
# ..                             ...
# 100         Rua General Sousa Neto
# 101  Rua Geraldo Vieira dos Santos
# 102       Avenida Giovanni Gronchi
# 103                Avenida Jamaris
# 104       Avenida Hélio Borenstein
#
# [105 rows x 6 columns]

# %%
# Função de separar 2 números com - e retornar a média

def calcular_media_intervalo(valor):
    if pd.isna(valor):  
        return 0
    valor = str(valor)
    if '-' in valor:
        partes = valor.split('-')
        return np.mean([float(parte) for parte in partes])
    return float(valor)

# %%
# Arrumar a coluna metragem, quartos, banheiros e vagas

df['metragem'] = df['metragem'].str.replace('Tamanho do imóvel\n', '', regex=False).str.replace('m²', '', regex=False)
df['metragem'] = df['metragem'].apply(calcular_media_intervalo)
df['metragem'] = df['metragem'].astype(float)

df['quartos'] = df['quartos'].str.replace('Quantidade de quartos\n', '', regex=False).fillna(0)
df['quartos'] = df['quartos'].apply(calcular_media_intervalo) 
df['quartos'] = df['quartos'].astype(float) 

df['banheiros'] = df['banheiros'].str.replace('Quantidade de banheiros\n', '', regex=False).fillna(0)
df['banheiros'] = df['banheiros'].apply(calcular_media_intervalo) 
df['banheiros'] = df['banheiros'].astype(float) 

df['vagas'] = df['vagas'].str.replace('Quantidade de vagas de garagem\n', '', regex=False).fillna(0)
df['vagas'] = df['vagas'].apply(calcular_media_intervalo) 
df['vagas'] = df['vagas'].astype(float) 

df
# Out:
#      metragem  quartos  banheiros  vagas  \
# 0       604.0      4.0        7.0    3.0
# 1        60.0      2.0        2.0    1.0
# 2        75.0      0.0        1.0    2.0
# 3        43.0      1.0        1.5    1.0
# 4       161.0      3.0        1.0    0.0
# ..        ...      ...        ...    ...
# 100      27.0      2.0        1.0    1.0
# 101     525.0      0.0        0.0    0.0
# 102      37.0      2.0        1.0    0.0
# 103     146.0      3.0        3.0    2.0
# 104     400.0      0.0        0.0    0.0
#
#                                            valor  \
# 0    R$ 11.800.000\nCond. R$ 1.659 • IPTU R$ 873
# 1         R$ 395.000\nCond. R$ 120 • IPTU R$ 130
# 2                                     R$ 350.000
# 3          R$ 180.000\nCond. R$ 430 • IPTU R$ 67
# 4                                     R$ 265.600
# ..                                           ...
# 100                                   R$ 199.900
# 101                     R$ 270.000\nCond. R$ 550
# 102                                   R$ 273.000
# 103   R$ 1.899.970\nCond. R$ 2.000 • IPTU R$ 700
# 104                    R$ 480.000\nIPTU R$ 2.459
#
#                            nomeRua
# 0                   Alameda Mamoré
# 1                      Rua Marília
# 2       Avenida Valentim Magalhães
# 3               Rua General Osório
# 4                              NaN
# ..                             ...
# 100         Rua General Sousa Neto
# 101  Rua Geraldo Vieira dos Santos
# 102       Avenida Giovanni Gronchi
# 103                Avenida Jamaris
# 104       Avenida Hélio Borenstein
#
# [105 rows x 6 columns]

# %%
# Separando o IPTU e o condominio do valor e transformando em float

df['condominio'] = df['valor'].str.extract(r'Cond\. R\$ ([\d.,]+)')[0].str.replace('.', '', regex=False).str.replace(',', '.', regex=False).astype(float).fillna(0)
df['iptu'] = df['valor'].str.extract(r'IPTU R\$ ([\d.,]+)')[0].str.replace('.', '', regex=False).str.replace(',', '.', regex=False).astype(float).fillna(0)
df['valor'] = df['valor'].str.extract(r'R\$ ([\d.,]+)')[0].str.replace('.', '', regex=False).str.replace(',', '.', regex=False).astype(float)

df.head(30)
# Out:
#     metragem  quartos  banheiros  vagas       valor  \
# 0      604.0      4.0        7.0    3.0  11800000.0
# 1       60.0      2.0        2.0    1.0    395000.0
# 2       75.0      0.0        1.0    2.0    350000.0
# 3       43.0      1.0        1.5    1.0    180000.0
# 4      161.0      3.0        1.0    0.0    265600.0
# 5      121.0      2.0        2.0    2.0    260000.0
# 6      100.0      2.0        2.0    2.0    430000.0
# 7       60.0      2.5        2.0    1.0    270000.0
# 8      147.0      3.0        2.0    3.0    380000.0
# 9      250.0      3.0        5.0    4.0   1700000.0
# 10      30.0      1.0        1.0    1.0    235000.0
# 11      82.0      3.0        2.0    2.0    850000.0
# 12      88.0      2.5        2.0    1.0    240000.0
# 13     109.0      3.0        3.0    2.0   1489970.0
# 14      51.0      2.0        1.0    1.0    271000.0
# 15     150.0      0.0        0.0    0.0    175000.0
# 16     163.0      3.0        5.0    3.0   1772750.0
# 17     104.0      2.0        2.0    1.0    400000.0
# 18      58.0      1.0        1.0    1.0    979970.0
# 19     100.0      3.0        2.0    1.0    330000.0
# 20      40.0      2.0        1.0    0.0    280000.0
# 21     132.0      3.0        2.0    2.0   1649980.0
# 22      67.0      2.0        1.5    1.5    387718.0
# 23     220.0      4.0        4.0    4.0   2349980.0
# 24     132.0      3.0        2.0    2.0   1649970.0
# 25      72.0      2.0        2.0    1.0    290000.0
# 26      88.0      3.0        2.0    2.0    380000.0
# 27     190.0      3.0        5.0    4.0   1490000.0
# 28      76.0      3.0        2.0    1.0    230000.0
# 29     180.0      2.0        1.0    2.0     78559.0
#
#                                 nomeRua  condominio    iptu
# 0                        Alameda Mamoré      1659.0   873.0
# 1                           Rua Marília       120.0   130.0
# 2            Avenida Valentim Magalhães         0.0     0.0
# 3                    Rua General Osório       430.0    67.0
# 4                                   NaN         0.0     0.0
# 5      Avenida Ernesto Guevara La Serna         0.0     0.0
# 6                       Rua Álvaro Lins       180.0   190.0
# 7            Avenida Presidente Kennedy       217.0     0.0
# 8                        Rua Bela Vista         0.0     0.0
# 9                        Rua dos Cravos       796.0   178.0
# 10            Avenida Braz Olaia Acosta       350.0     0.0
# 11            Rua Padre Manoel de Paiva       880.0    60.0
# 12  Avenida Doutor Antônio Alves Passig       370.0     0.0
# 13                     Rua Dona Brígida      1600.0   638.0
# 14              Avenida Reserva do Japy       475.0    51.0
# 15               Rua Suely Aragão Rocha         0.0     0.0
# 16              Rua Doutor Rubens Awada         0.0     0.0
# 17                         Rua São João         0.0     0.0
# 18            Rua José Augusto Penteado      1023.0   495.0
# 19           Rua Antônio Carlos Pereira         0.0     0.0
# 20                         Rua Hercília         0.0     0.0
# 21                       Avenida Jurema      2323.0   489.0
# 22                           Rua Dallas         0.0     0.0
# 23              Rua Gabriele D'Annunzio      3200.0  1970.0
# 24                       Avenida Jurema      2323.0   489.0
# 25                    Rua Estrela Velha         0.0     0.0
# 26   Alameda José de Oliveira Guimarães         1.0   100.0
# 27  Estrada Velha Indaiatuba - Campinas         0.0     0.0
# 28               Avenida Aspirante Mega       230.0   100.0
# 29                           Quadra C 1         0.0     0.0

# %%
# normalizando o nomeRua
df['nomeRua'] = df['nomeRua'].fillna('Rua não encontrada').str.title().str.strip()

# %%
# Renomeando a coluna metragem
df.rename(columns={'metragem': 'metragem(m²)'}, inplace=True)

# %%
# visualização 
display(df)
# Out:
#      metragem(m²)  quartos  banheiros  vagas       valor  \
# 0           604.0      4.0        7.0    3.0  11800000.0
# 1            60.0      2.0        2.0    1.0    395000.0
# 2            75.0      0.0        1.0    2.0    350000.0
# 3            43.0      1.0        1.5    1.0    180000.0
# 4           161.0      3.0        1.0    0.0    265600.0
# ..            ...      ...        ...    ...         ...
# 100          27.0      2.0        1.0    1.0    199900.0
# 101         525.0      0.0        0.0    0.0    270000.0
# 102          37.0      2.0        1.0    0.0    273000.0
# 103         146.0      3.0        3.0    2.0   1899970.0
# 104         400.0      0.0        0.0    0.0    480000.0
#
#                            nomeRua  condominio    iptu
# 0                   Alameda Mamoré      1659.0   873.0
# 1                      Rua Marília       120.0   130.0
# 2       Avenida Valentim Magalhães         0.0     0.0
# 3               Rua General Osório       430.0    67.0
# 4               Rua Não Encontrada         0.0     0.0
# ..                             ...         ...     ...
# 100         Rua General Sousa Neto         0.0     0.0
# 101  Rua Geraldo Vieira Dos Santos       550.0     0.0
# 102       Avenida Giovanni Gronchi         0.0     0.0
# 103                Avenida Jamaris      2000.0   700.0
# 104       Avenida Hélio Borenstein         0.0  2459.0
#
# [105 rows x 8 columns]

# %%
# Salvar em um novo excel

df.to_excel('casas_limpo.xlsx', index=False)
